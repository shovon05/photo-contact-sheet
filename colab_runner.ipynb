# %% [markdown]
# <a href="https://colab.research.google.com/github/shovon05/photo-contact-sheet/blob/main/colab_runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📸 Photo Contact Sheet Generator
#
# This notebook generates printable A4 photo sheets from a folder in Google Drive.

# %%
# !pip install pillow pillow-heif tqdm numpy
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Collecting pillow-heif
#   Downloading pillow_heif-1.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Downloading pillow_heif-1.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 11.0 MB/s eta 0:00:00
# Installing collected packages: pillow-heif
# Successfully installed pillow-heif-1.3.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/shovon05/photo-contact-sheet.git
# %cd photo-contact-sheet
# Out:
# Cloning into 'photo-contact-sheet'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 28 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 11.22 KiB | 11.22 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/photo-contact-sheet

# %%
photo_size=float(input("📏 Enter photo size (inches): "))

margin_choice=input("📐 Add margin? yes/no: ")

margin=0
if margin_choice.lower()=="yes":
    margin=float(input("Enter margin size in inches: "))
# Out:
# 📏 Enter photo size (inches): 1
# 📐 Add margin? yes/no: no

# %%
from contact_sheet import generate_contact_sheet

generate_contact_sheet(
    image_folder="/content/drive/MyDrive/photos",
    output_pdf="/content/drive/MyDrive/photo_sheets.pdf",
    photo_size_in=photo_size,
    margin_in=margin
)
# Out:
# Grid: 8 x 11
# Photos per page: 88
#  29%|██▊       | 273/953 [04:24<09:19,  1.21it/s]
